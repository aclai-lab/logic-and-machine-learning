# %% [markdown]
# # Hello, World!
#
# Welcome to the first lesson of the *Logic and Machine Learning* course!
#
# The goal of this notebook is to getting familiar with Julia and, in particular, with some of the functionalities offered by `SoleLogics.jl` library (e.g., manipulating formulae).
#
# If you missed the setup instructions, please refer to the `README.md` file in the root folder.

# %% [markdown]
# # Pkg.jl
#
# `Pkg` is a built-in library we can leverage for easily manage the project we are working in.
# Instead of manually writing esoteric configuration files, we can do everything by simply executing `Pkg.mycommand(...)`.
#
# For example, if we want to add a new dependency `foo.jl` to our project, we need to execute `Pkg.add("foo")`, and all the necessary data will be downloaded from the [Julia general package registry](https://github.com/JuliaRegistries/General). Then, the changing is tracked in a `Project.toml` file.
#
# You can guess what `Pkg.remove("foo")` does.
#
# To load an already existing `Project.toml`, or to create a new one, you can use `Pkg.activate` and specify a relative filepath.
#
# `Pkg.instantiate` reads the loaded configuration and resolves it, that is, it tries to precompile all the specified packages, taking care of versioning and populating a `Manifest.toml` file with metadata that we never want to manually change.
#
# `Pkg.update` forces `Pkg` to visit the general registry and install the newest updates that respect all the versioning constraints of the project.
#
# Finally, `Pkg.status` consists of a summary of all the dependencies we are dealing with. They will be useful throughout all the lessons.

# %%
using Pkg
Pkg.activate("..")
Pkg.instantiate()
Pkg.update()
Pkg.status()
# Out:
#   Activating project at `~/.julia/dev/logic-and-machine-learning`
# Precompiling project...
#     746.5 ms  ✓ IteratorInterfaceExtensions
#     837.9 ms  ✓ LaTeXStrings
#     934.6 ms  ✓ ScientificTypesBase
#     981.8 ms  ✓ WorkerUtilities
#     971.1 ms  ✓ UniqueVectors
#    1083.3 ms  ✓ Contour
#    1109.2 ms  ✓ TensorCore
#    1145.0 ms  ✓ ExprTools
#    1223.7 ms  ✓ StatsAPI
#    1756.3 ms  ✓ FunctionWrappers
#     958.4 ms  ✓ Measures
#     854.1 ms  ✓ PrettyPrint
#     972.3 ms  ✓ ThreadSafeDicts
#     912.0 ms  ✓ ArgCheck
#    1099.8 ms  ✓ InverseFunctions
#     901.4 ms  ✓ ShowCases
#    1048.3 ms  ✓ Statistics
#    2113.4 ms  ✓ InitialValues
#    1307.8 ms  ✓ IterTools
#     703.5 ms  ✓ DataValueInterfaces
#    1994.2 ms  ✓ FillArrays
#    2844.8 ms  ✓ Format
#     849.8 ms  ✓ Reexport
#    1050.2 ms  ✓ StableRNGs
#    1152.8 ms  ✓ TZJData
#    1232.9 ms  ✓ Requires
#    1397.5 ms  ✓ Unzip
#    1446.8 ms  ✓ DocStringExtensions
#    1793.6 ms  ✓ Grisu
#     779.4 ms  ✓ SimpleBufferStream
#    1026.7 ms  ✓ IntervalSets
#    1409.4 ms  ✓ InlineStrings
#     863.2 ms  ✓ CompositionsBase
#    3992.6 ms  ✓ UnsafeAtomics
#    1304.0 ms  ✓ AbstractTrees
#    1034.1 ms  ✓ Extents
#     851.9 ms  ✓ PtrArrays
#    1533.3 ms  ✓ URIs
#    1009.9 ms  ✓ Interfaces
#     781.2 ms  ✓ DefineSingletons
#     822.3 ms  ✓ HashArrayMappedTries
#    1190.1 ms  ✓ TranscodingStreams
#     911.8 ms  ✓ InvertedIndices
#    1063.8 ms  ✓ NaNMath
#    1186.2 ms  ✓ DelimitedFiles
#     940.1 ms  ✓ Inflate
#    2480.8 ms  ✓ IrrationalConstants
#     862.5 ms  ✓ DataAPI
#    1018.0 ms  ✓ ConstructionBase
#     882.4 ms  ✓ BitFlags
#     962.5 ms  ✓ Indexing
#    1244.3 ms  ✓ ProgressLogging
#    1314.9 ms  ✓ StaticArraysCore
#    1506.9 ms  ✓ SuiteSparse
#    2046.1 ms  ✓ ZipFile
#    2238.3 ms  ✓ ConcurrentUtilities
#    5874.5 ms  ✓ MacroTools
#    1671.3 ms  ✓ Scratch
#    3244.4 ms  ✓ Crayons
#    1761.8 ms  ✓ LoggingExtras
#    1353.4 ms  ✓ Compat
#    2998.1 ms  ✓ Baselet
#    2447.0 ms  ✓ StructUtils
#    2721.8 ms  ✓ ProgressMeter
#    1164.0 ms  ✓ JLLWrappers
#    1069.3 ms  ✓ PrecompileTools
#    1112.6 ms  ✓ ExceptionUnwrapping
#    2971.6 ms  ✓ MbedTLS
#    3492.6 ms  ✓ SentinelArrays
#    1001.3 ms  ✓ TableTraits
#    1019.5 ms  ✓ StatisticalTraits
#    1055.7 ms  ✓ NameResolution
#    1122.4 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    1440.4 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    1279.7 ms  ✓ ScikitLearnBase
#     990.7 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1261.0 ms  ✓ Statistics → SparseArraysExt
#    1116.0 ms  ✓ Adapt
#    1104.4 ms  ✓ Showoff
#     869.8 ms  ✓ IntervalSets → IntervalSetsRandomExt
#    1373.1 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    2794.7 ms  ✓ Revise → DistributedExt
#     881.0 ms  ✓ IntervalSets → IntervalSetsStatisticsExt
#     887.4 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    3465.8 ms  ✓ UnicodeFun
#    1164.8 ms  ✓ Atomix
#     870.7 ms  ✓ ScopedValues
#     994.3 ms  ✓ AliasTables
#    1036.8 ms  ✓ CodecZlib
#    2686.1 ms  ✓ DataValues
#    1003.5 ms  ✓ PooledArrays
#     908.0 ms  ✓ Missings
#     924.0 ms  ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#    1533.1 ms  ✓ LogExpFunctions
#    1024.4 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    1281.5 ms  ✓ RelocatableFolders
#    1266.5 ms  ✓ Compat → CompatLinearAlgebraExt
#    1969.9 ms  ✓ OpenSSL_jll
#    2413.0 ms  ✓ PDMats
#    1883.4 ms  ✓ catch22_jll
#    2269.1 ms  ✓ SimpleTraits
#    1762.0 ms  ✓ Libmount_jll
#    2266.0 ms  ✓ Graphite2_jll
#    3208.7 ms  ✓ Dictionaries
#    6086.1 ms  ✓ FixedPointNumbers
#    1851.4 ms  ✓ EpollShim_jll
#    2023.3 ms  ✓ LLVMOpenMP_jll
#    1492.5 ms  ✓ Bzip2_jll
#    1409.8 ms  ✓ Xorg_libICE_jll
#    1536.5 ms  ✓ Rmath_jll
#    1635.3 ms  ✓ Xorg_libXau_jll
#    1618.0 ms  ✓ libpng_jll
#    1616.6 ms  ✓ libfdk_aac_jll
#    1654.9 ms  ✓ LAME_jll
#    1470.4 ms  ✓ LERC_jll
#    1624.8 ms  ✓ fzf_jll
#    1423.4 ms  ✓ Ogg_jll
#    1544.1 ms  ✓ mtdev_jll
#    1885.4 ms  ✓ JpegTurbo_jll
#    1859.5 ms  ✓ XZ_jll
#    1582.9 ms  ✓ x265_jll
#    5910.3 ms  ✓ Lazy
#    1807.5 ms  ✓ Xorg_libXdmcp_jll
#    1690.5 ms  ✓ x264_jll
#    1669.6 ms  ✓ Zstd_jll
#    1705.9 ms  ✓ libaom_jll
#    1661.5 ms  ✓ Expat_jll
#    1253.7 ms  ✓ Xorg_xtrans_jll
#    1494.6 ms  ✓ LZO_jll
#    1494.2 ms  ✓ libevdev_jll
#    1383.3 ms  ✓ Libffi_jll
#    1815.3 ms  ✓ Opus_jll
#    1705.6 ms  ✓ Libiconv_jll
#    2114.2 ms  ✓ eudev_jll
#    2227.3 ms  ✓ OpenSpecFun_jll
#    2294.8 ms  ✓ FriBidi_jll
#    2384.8 ms  ✓ Libuuid_jll
#   11410.2 ms  ✓ FileIO
#    1905.2 ms  ✓ Adapt → AdaptSparseArraysExt
#    2882.7 ms  ✓ Tables
#    1686.5 ms  ✓ ArrayInterface
#    1379.9 ms  ✓ TableTraitsUtils
#     996.6 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    1554.5 ms  ✓ GPUArraysCore
#    3667.3 ms  ✓ DecisionTree
#    4070.6 ms  ✓ MLJModelInterface
#    1752.1 ms  ✓ Mocking
#    6102.5 ms  ✓ RecipesBase
#    1847.6 ms  ✓ ContextVariablesX
#    3014.0 ms  ✓ FilePathsBase
#    7159.7 ms  ✓ StringManipulation
#    4113.9 ms  ✓ Setfield
#    4521.3 ms  ✓ ChainRulesCore
#    2062.4 ms  ✓ FillArrays → FillArraysPDMatsExt
#    1987.2 ms  ✓ Pixman_jll
#    1677.4 ms  ✓ FreeType2_jll
#    1737.1 ms  ✓ Xorg_libSM_jll
#    5605.3 ms  ✓ DataStructures
#    5028.8 ms  ✓ CategoricalArrays
#    2135.1 ms  ✓ Rmath
#    6965.0 ms  ✓ Accessors
#    1906.0 ms  ✓ libvorbis_jll
#    2588.5 ms  ✓ JLFzf
#    1943.8 ms  ✓ Libtiff_jll
#    4796.2 ms  ✓ ColorTypes
#    6311.4 ms  ✓ OpenSSL
#    1952.9 ms  ✓ Dbus_jll
#    1315.9 ms  ✓ StructUtils → StructUtilsTablesExt
#    3524.6 ms  ✓ Ghostscript_jll
#    1987.4 ms  ✓ libinput_jll
#    2200.1 ms  ✓ Wayland_jll
#    2251.8 ms  ✓ GettextRuntime_jll
#    1054.4 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    1490.3 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#     988.2 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#    4532.4 ms  ✓ Xorg_libxcb_jll
#    1262.5 ms  ✓ IterableTables
#    1062.9 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#    2779.1 ms  ✓ MLCore
#    1497.5 ms  ✓ IntervalSets → IntervalSetsRecipesBaseExt
#    1787.4 ms  ✓ FLoopsBase
#    1244.5 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    1585.0 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    2752.6 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#    1470.0 ms  ✓ SortingAlgorithms
#    3112.6 ms  ✓ SplittablesBase
#    2830.4 ms  ✓ Fontconfig_jll
#    1321.2 ms  ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#    1374.4 ms  ✓ Accessors → LinearAlgebraExt
#    2387.3 ms  ✓ CategoricalArrays → CategoricalArraysRecipesBaseExt
#    2548.2 ms  ✓ QuadGK
#    4087.8 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1308.0 ms  ✓ Accessors → IntervalSetsExt
#    1445.4 ms  ✓ Accessors → TestExt
#    7609.5 ms  ✓ SpecialFunctions
#    1338.4 ms  ✓ ColorTypes → StyledStringsExt
#    2484.3 ms  ✓ Xorg_xcb_util_jll
#    3062.1 ms  ✓ Xorg_libX11_jll
#    4006.1 ms  ✓ Glib_jll
#   22817.1 ms  ✓ StaticArrays
#    8040.5 ms  ✓ ColorVectorSpace
#    3962.1 ms  ✓ BangBang
#    2557.0 ms  ✓ Xorg_xcb_util_image_jll
#    6242.7 ms  ✓ HypergeometricFunctions
#    3802.6 ms  ✓ Xorg_xcb_util_keysyms_jll
#   10128.5 ms  ✓ StatsBase
#    4051.1 ms  ✓ Xorg_xcb_util_renderutil_jll
#   14247.0 ms  ✓ Latexify
#   10157.8 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    3225.5 ms  ✓ Xorg_libXrender_jll
#    3704.1 ms  ✓ Xorg_xcb_util_wm_jll
#    2167.7 ms  ✓ Xorg_libXext_jll
#    2320.0 ms  ✓ Xorg_libXfixes_jll
#   22013.4 ms  ✓ TimeZones
#    2778.0 ms  ✓ Xorg_libxkbfile_jll
#    2218.9 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    2260.4 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    2914.7 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   49986.5 ms  ✓ MLStyle
#    2117.4 ms  ✓ Adapt → AdaptStaticArraysExt
#    4110.7 ms  ✓ ArnoldiMethod
#    2538.6 ms  ✓ Accessors → StaticArraysExt
#    1869.4 ms  ✓ BangBang → BangBangTablesExt
#    2060.2 ms  ✓ BangBang → BangBangChainRulesCoreExt
#    2523.5 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    2747.4 ms  ✓ BangBang → BangBangStaticArraysExt
#    2912.6 ms  ✓ PDMats → StatsBaseExt
#    3426.7 ms  ✓ MicroCollections
#    2772.6 ms  ✓ Xorg_xcb_util_cursor_jll
#    2534.3 ms  ✓ Xorg_libXinerama_jll
#    3247.2 ms  ✓ CategoricalArrays → CategoricalArraysStatsBaseExt
#   22839.8 ms  ✓ Colors
#    3101.6 ms  ✓ Latexify → SparseArraysExt
#   40537.7 ms  ✓ Parsers
#    3773.7 ms  ✓ Discretizers
#    1812.8 ms  ✓ Xorg_libXrandr_jll
#    1554.1 ms  ✓ Xorg_libXi_jll
#    2344.5 ms  ✓ Libglvnd_jll
#    1774.2 ms  ✓ Xorg_libXcursor_jll
#    1561.7 ms  ✓ TimeZones → TimeZonesRecipesBaseExt
#    2059.4 ms  ✓ Cairo_jll
#    5909.8 ms  ✓ StatsFuns
#    1712.3 ms  ✓ Xorg_xkbcomp_jll
#    1428.4 ms  ✓ InlineStrings → ParsersExt
#    1858.6 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    2369.5 ms  ✓ HarfBuzz_jll
#    1889.7 ms  ✓ Xorg_xkeyboard_config_jll
#    4709.0 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    7785.7 ms  ✓ JuliaVariables
#    2476.2 ms  ✓ WeakRefStrings
#    7758.7 ms  ✓ Transducers
#    8086.4 ms  ✓ SoleBase
#    2789.1 ms  ✓ libass_jll
#    2418.4 ms  ✓ xkbcommon_jll
#    2838.3 ms  ✓ Pango_jll
#   11683.7 ms  ✓ KernelAbstractions
#    3645.3 ms  ✓ Transducers → TransducersAdaptExt
#   11862.1 ms  ✓ JSON
#    2858.6 ms  ✓ Vulkan_Loader_jll
#    2294.9 ms  ✓ libdecor_jll
#   13225.0 ms  ✓ ColorSchemes
#    4118.9 ms  ✓ FFMPEG_jll
#   14685.9 ms  ✓ Graphs
#    2055.6 ms  ✓ KernelAbstractions → LinearAlgebraExt
#    2475.0 ms  ✓ KernelAbstractions → SparseArraysExt
#    1643.4 ms  ✓ TableShowUtils
#    1752.8 ms  ✓ CategoricalArrays → CategoricalArraysJSONExt
#    2258.6 ms  ✓ GLFW_jll
#    3964.5 ms  ✓ BenchmarkTools
#    2367.5 ms  ✓ FFMPEG
#    3502.9 ms  ✓ Qt6Base_jll
#   15579.5 ms  ✓ Distributions
#    2945.0 ms  ✓ QueryOperators
#    1896.1 ms  ✓ Qt6ShaderTools_jll
#    2445.5 ms  ✓ GR_jll
#   10460.9 ms  ✓ FLoops
#    2613.0 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    2757.1 ms  ✓ Distributions → DistributionsTestExt
#    2592.9 ms  ✓ Query
#    4390.3 ms  ✓ Qt6Declarative_jll
#    3684.0 ms  ✓ Qt6Wayland_jll
#   13971.4 ms  ✓ NNlib
#   54101.7 ms  ✓ DimensionalData
#    2135.6 ms  ✓ NNlib → NNlibSpecialFunctionsExt
#   55903.8 ms  ✓ HTTP
#    1846.0 ms  ✓ FileIO → HTTPExt
#    3265.3 ms  ✓ TimeseriesFeatures
#    3991.0 ms  ✓ TimeseriesFeatures → StatsBaseExt
#   27697.0 ms  ✓ PlotUtils
#   11732.0 ms  ✓ GR
#   18633.1 ms  ✓ MLUtils
#   43056.5 ms  ✓ CSV
#    9116.1 ms  ✓ PlotThemes
#   11769.3 ms  ✓ RecipesPipeline
#   20386.5 ms  ✓ Catch22
#   84132.5 ms  ✓ PrettyTables
#    3008.6 ms  ✓ ScientificTypes
#   12715.4 ms  ✓ SoleLogics
#   40552.7 ms  ✓ DataFrames
#    2005.9 ms  ✓ Latexify → DataFramesExt
#    2034.0 ms  ✓ Transducers → TransducersDataFramesExt
#    2399.7 ms  ✓ BangBang → BangBangDataFramesExt
#    6338.3 ms  ✓ RData
#    7349.1 ms  ✓ MultiData
#    3957.7 ms  ✓ RDatasets
#   14965.2 ms  ✓ SoleData
#   67540.3 ms  ✓ Plots
#    2930.2 ms  ✓ Plots → FileIOExt
#   308 dependencies successfully precompiled in 185 seconds. 47 already precompiled.
#   1 dependency had output during precompilation:
# ┌ SoleData
# │  WARNING: using SoleLogics.threshold in module PLA conflicts with an existing identifier.
# └
#     Updating registry at `~/.julia/registries/General`
# ┌ Info: The General registry is installed via git. Consider reinstalling it via
# │ the newer faster direct from tarball format by running:
# │   pkg> registry rm General; registry add General
# │
# └ @ Pkg.Registry /home/mauro/.julia/juliaup/julia-1.11.8+0.x64.linux.gnu/share/julia/stdlib/v1.11/Pkg/src/Registry/Registry.jl:478
#     Updating git-repo `https://github.com/JuliaRegistries/General`
#   No Changes to `~/.julia/dev/logic-and-machine-learning/Project.toml`
#     Updating `~/.julia/dev/logic-and-machine-learning/Manifest.toml`
#   [05823500] ↑ OpenLibm_jll v0.8.1+2 ⇒ v0.8.5+0
# Status `~/.julia/dev/logic-and-machine-learning/Project.toml`
#   [6e4b80f9] BenchmarkTools v1.6.3
#   [7806a523] DecisionTree v0.12.4
#   [f1d291b0] MLUtils v0.4.8
#   [91a5bcdd] Plots v1.41.3
#   [ce6b1742] RDatasets v0.8.0
#   [123f1ae1] SoleData v0.16.6
#   [b002da8f] SoleLogics v0.13.5
#   [9a3f8284] Random v1.11.0

# %% [markdown]
# # A Julia Cheatsheet
#
# The cells below contains everything you need to start playing with the Julia language.
#
# You can execute them one after the other, by simpling selecting the first cell and then pressing `SHIFT + ENTER`.
#
# Let us start with the very fundamentals.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
1 + 4
(1 - 5) + (9 * 2)
6 / 5;  # if you remove the ";", then the result is automatically printed

# %%
35 % 8      # modulo
div(9, 7)   # integer division
9^3         # exponentiation
big(2)^38461
# Out:
# ...

# %%
true
false

true && false   # logical and
true || false   # or
!true           # not
# Out:
# false

# %%
26 < 43
38 > 32
79 <= 50    # less or equal than
28 >= 84
19 == 71    # equal
69 != 39    # not equal
# Out:
# true

# %%
"lexicographical" > "comparison"
# Out:
# true

# %%
foo = "string"  # this is a variable
print("This is a $(foo) interpolation!")
# Out:
# This is a string interpolation!

# %% [markdown]
# # Variables and Types
#
# Variable names start with a letter or an underscore, and they can't be declared without a value.
#
# We can play with all the variables appearing in the previously executed cells.
#
# Every variable is associated with a *type*, and types are organized in hierarchical structures of *abstract types*.
#
# The very bottom of this hierarchical structure includes the *concrete types*, and variables are particular instantiations of such types.
#
# We can investigate the types of a variable using `typeof`, `supertype` and `subtypes`.

# %%
println(typeof(foo))
println(supertype(typeof(foo)))
println(supertype(supertype(typeof(foo))))
# Out:
# String
# AbstractString
# Any

# %%
bar = 93
bar |> typeof |> println # this is just a more readable rewriting for println(typeof(bar))
bar |> typeof |> supertype |> println
bar |> typeof |> supertype |> supertype |> println
bar |> typeof |> supertype |> supertype |> supertype |> println
# Out:
# Int64
# Signed
# Integer
# Real

# %%
baz = 75.10
current_type = typeof(baz)

while current_type != Any
    println(current_type)
    current_type = supertype(current_type)
end
# Out:
# Float64
# AbstractFloat
# Real
# Number

# %%
subtypes(Integer)
# Out:
# 3-element Vector{Any}:
#  Bool
#  Signed
#  Unsigned

# %%
Integer <: Number
# Out:
# true

# %%
Int <: Integer <: Number # Int is a renaming for Int64
# Out:
# true

# %% [markdown]
# ### Special Variables and Special Types
#
# Variables can hold special values to gracefully handle errors, such as the Float64 `NaN` value.
#
# Particular semantics are conveyed by unique types, such as `Nothing`, `Symbol` and `Union`.
#
# The former type can only be instantiated with the value `nothing`.
#
# Symbols are used to encode uninterpreted names instead of values, and helps when dealing with [metaprogramming](https://docs.julialang.org/en/v1/manual/metaprogramming/).
#
# Unions are special types, representing many types all at once.

# %%
println(0/0)
println(isnan(0/0))
# Out:
# NaN
# true

# %%
# this is a special variable representing... the absence of any value
placeholder = nothing
isnothing(placeholder)
# Out:
# true

# %%
print_return_value = println("Println does not return anything")
println(print_return_value)
# Out:
# Println does not return anything
# nothing

# %%
# symbols are special values intended to represent names rather than values
plussymbol = Symbol("+")
xsymbol = Symbol("x")
twosymbol = Symbol("2")
# Out:
# Symbol("2")

# %%
x = 10
expr = :(x + 2)
dump(expr)
# Out:
# Expr
#   head: Symbol call
#   args: Array{Any}((3,))
#     1: Symbol +
#     2: Symbol x
#     3: Int64 2

# %%
const MyCustomType = Union{Float64,String}
# Out:
# Union{Float64, String}

# %%
# this is a synonym of: typeof("papadimitriou") <: MyCustomType
"papadimitriou" isa MyCustomType
# Out:
# true

# %%
:papadimitriou isa MyCustomType
# Out:
# false

# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Data Structures: Tuples
#
# Tuples are *immutable* fixed-length containers: if you want to modify them, you have to recreate them completely.
#
# We can explicitly state the type that each of the element within a tuple must have by enclosing them in curly brackets; actually, we could just let Julia infer them.

# %%
qux = Tuple{Int64, Float64}((58, 20.9)) # shorthand for (12, 23.2)
# Out:
# (58, 20.9)

# %%
typeof(qux)
# Out:
# Tuple{Int64, Float64}

# %%
try
    qux[1] = qux[1] + 2
catch
    println("Remember that tuples are are immutable!")
end
# Out:
# Remember that tuples are are immutable!

# %% [markdown]
# ## Data Structures: Arrays
#
# An array is anything that implements the [`AbstractArray`](https://docs.julialang.org/en/v1/manual/interfaces/#man-interface-array) interface.
#
# To put it simple, `Array{T,N}` are dynamic collections of dimensionality `N`, embodying elements of type `T`.
#
# The type `Array{Float64,1}` encodes *vectors*, while `Array{Float64,2}` encodes *matrices*.
#
# Note that the dimension number is not a type by itself, as it is an integer, but it is treated like a type in this context, essentially for optimization purposes.

# %%
baz = [74, 94]
typeof(baz)
# Out:
# Vector{Int64} (alias for Array{Int64, 1})

# %%
push!(baz, 4)
println(baz)
# Out:
# [74, 94, 4]

# %%
try
    push!(baz, 5.9)
catch
    println("You can't push a Float64 into a $(typeof(baz))")
end
# Out:
# You can't push a Float64 into a Vector{Int64}

# %%
baz = convert(Vector{Float64}, baz)
# Out:
# 3-element Vector{Float64}:
#  74.0
#  94.0
#   4.0

# %%
baz = [23, 0.7, 81] # the automatic conversion to Vector{Float64} is due to a promotion rule
promote_rule(Float64, Int)
# Out:
# Float64

# %%
println("The content of baz is: $(baz)")
println("The length of baz is: $(length(baz))")
println("The size of baz is: $(size(baz))")
println("The first element of baz is: $(baz[1])")
println("The first two elements of baz are: $(baz[1:2])")
println("The last element is: $(baz[end])")
# Out:
# The content of baz is: [23.0, 0.7, 81.0]
# The length of baz is: 3
# The size of baz is: (3,)
# The first element of baz is: 23.0
# The first two elements of baz are: [23.0, 0.7]
# The last element is: 81.0

# %%
println("The minimum of baz is: $(minimum(baz))")
println("The maximum of baz is: $(maximum(baz))") 
println("The sum of baz is: $(sum(baz))")
# Out:
# The minimum of baz is: 0.7
# The maximum of baz is: 81.0
# The sum of baz is: 104.7

# %%
mysum = 0

for n in baz
    mysum += n
end

println("The 'manually computed' sum of baz is: $(mysum)")
# Out:
# The 'manually computed' sum of baz is: 104.7

# %%
for (i,n) in enumerate(baz)
    println("The element $(i) of baz is: $(baz[i])")
end
# Out:
# The element 1 of baz is: 23.0
# The element 2 of baz is: 0.7
# The element 3 of baz is: 81.0

# %%
for (n, next_n) in zip(baz, baz[2:end])
    println("$(n)\t$(next_n)") # \t is the tabulation character
end
# Out:
# 23.0	0.7
# 0.7	81.0

# %%
# an int vector is not a subtype of a vector containing elements of arbitrary Real types
# (even floats!)
Vector{Int} <: Vector{Real}
# Out:
# false

# %%
# same reasoning if we consider the whole family of Int8, Int32, Int64...
Vector{Integer} <: Vector{Real}
# Out:
# false

# %%
# this is fine
Vector{Int} <: Vector{<:Real}
# Out:
# true

# %% [markdown]
# ## Data Structures: Dictionaries
#
# Dictionaries are hash tables `Dict{K,V}` with keys of type `K` and values of type `V`.
#
# Under the hood, keys are hashed using the `hash` function of the Julia standard library.

# %%
mydict = Dict{Int, Float64}(74 => 9.4, 45 => 9.2)
# Out:
# Dict{Int64, Float64} with 2 entries:
#   45 => 9.2
#   74 => 9.4

# %%
mydict[74]
# Out:
# 9.4

# %%
9.2 in values(mydict)
# Out:
# true

# %%
try
    mydict[30]
catch
    println("The dictionary does not contain a key with value 30.")
end
# Out:
# The dictionary does not contain a key with value 30.

# %%
# we can provide a default value for non-existing entries
get(mydict, 30, -1)
# Out:
# -1

# %%
metadict = Dict{String, Dict{Int, Float64}}(
    "logic" => mydict,
    "machine learning" => mydict
)

metadict["logic"] == mydict
# Out:
# true

# %% [markdown]
# ### Beware...
# The two dictionaries within `metadict` are not copied by value, but by reference.

# %%
println("The values associated with key 74 in the two dictionaries are:")
for (key, innerdict) in metadict 
    println(innerdict[74])
end

println()

for (key, innerdict) in metadict 
    println("I am adding one in the $(key == "logic" ? "first" : "second") dictionary")
    innerdict[74] += 1
end

println("\nThe values associated with key 74 in the two dictionaries are:")
for (key, innerdict) in metadict 
    println(innerdict[74])
end
# Out:
# The values associated with key 74 in the two dictionaries are:
# 9.4
# 9.4
#
# I am adding one in the first dictionary
# I am adding one in the second dictionary
#
# The values associated with key 74 in the two dictionaries are:
# 11.4
# 11.4

# %%
o1, o2 = objectid(metadict["logic"]), objectid(metadict["machine learning"])

println(objectid(metadict["logic"]))
println(objectid(metadict["machine learning"]))

# === is the "identical" operator: it queries the id associated with each variable under 
# the hood, rather than just their values
println(o1 === o2)
# Out:
# 4194168145268845936
# 4194168145268845936
# true

# %%
mydict[78] = 16.40
mydict
# Out:
# Dict{Int64, Float64} with 3 entries:
#   78 => 16.4
#   45 => 9.2
#   74 => 11.4

# %%
# when a function ends with a bang, it usually modifies its first argument
delete!(mydict, 78) # use pop! if you also want to retrieve the deleted pair
# Out:
# Dict{Int64, Float64} with 2 entries:
#   45 => 9.2
#   74 => 11.4

# %% [markdown]
# # Data Structures: Sets
#
# Sets are unordered collections of unique elements.
#
# They allow for efficient union, intersection and difference set operations.
#
# We can leverage the `in` operator or `issubset` for checking the membership to a set.

# %%
myset1 = Set{String}(["this", "is", "my", "beautiful", "set"]);
myset2 = Set{String}(["look", "at", "this", "beautiful", "set"]);

# %%
union(myset1, myset2)
# Out:
# Set{String} with 7 elements:
#   "this"
#   "is"
#   "set"
#   "beautiful"
#   "at"
#   "my"
#   "look"

# %%
intersect(myset1, myset2)
# Out:
# Set{String} with 3 elements:
#   "this"
#   "set"
#   "beautiful"

# %%
setdiff(myset1, myset2)
# Out:
# Set{String} with 2 elements:
#   "is"
#   "my"

# %%
setdiff(myset2, myset1)
# Out:
# Set{String} with 2 elements:
#   "at"
#   "look"

# %%
if "my" in myset1
    println("The string 'my' ∈ myset1.")
end

myset3 = Set(["this", "is", "set"])
if issubset(myset3, myset1)
    println("Also, 'this', 'is', and 'set' strings all belong to myset1")
end
# Out:
# The string 'my' ∈ myset1.
# Also, 'this', 'is', and 'set' strings all belong to myset1

# %% [markdown]
# # Functions
#
# Functions are mappings between a tuple of arguments and a return value.
# Julia functions are first-class citizens, meaning that they can be passed as arguments to other functions, they can be returned from function and can be stored in data structures.
#
# Functions in Julia can have multiple implementations, each specialized to a specific combination of arguments.
# This idea of multiple dispatching is at the core of the design of Julia, and enables fast computations.

# %%
function add(x, y)
    return x + y    # if the return keyword is omitted, the last operation is returned 
end

add(1, 2)
# Out:
# 3

# %%
subtract(x, y) = x - y

subtract(1, 2)
# Out:
# -1

# %%
# this function returns an anonymous (i.e., nameless) function 
add_five = x -> x + 5

add_five(1)
# Out:
# 6

# %%
# a function can even return a function
divide_by(y) = return x -> x / y

divide_by(5)(10)
# Out:
# 2.0

# %%
# functions can return multiple values
function powers(x)
    return x, x^2, x^3
end

a, b, c = powers(3)
# Out:
# (3, 9, 27)

# %%
typeofpowers = typeof(powers)

println(typeofpowers)
println(supertype(typeofpowers))
# Out:
# typeof(powers)
# Function

# %%
# function's names may contain unicode characters and a variable number of arguments
function ∑(args...)
    c = 0

    for arg in args
        c += arg
    end

    return c
end

∑(5, 6, 3, 4, 12)
# Out:
# 30

# %%
# functions may provide default values for their arguments
function power(x, y=2)
    return x ^ y
end

power(5)
# Out:
# 25

# %%
power.(collect(0:10)) # 1:10 is a synonym for 1:1:10, that is, go from 0 to 10 with step 1
# Out:
# 11-element Vector{Int64}:
#    0
#    1
#    4
#    9
#   16
#   25
#   36
#   49
#   64
#   81
#  100

# %%
function myprint(x::Int64)
    println("This is an awesome print for the number $(x)")
end

function myprint(x::Float64)
    println("This is a beautiful print for the number $(x)")
end

myprint(1)
myprint(1.0)
# Out:
# This is an awesome print for the number 1
# This is a beautiful print for the number 1.0

# %%
# note the difference between positional and keyword arguments;
# the former are identified by their position in the function signature,
# while the latter are recognized by their name when providing a value.
function myprint(x::String; mode::Symbol=:plain)

    if mode == :plain
        punctuation = ["", ""]
    elseif mode == :punctuation
        punctuation=[",", "."]
    else
        throw(ArgumentError("The specified mode $(mode) is not available."))
    end

    println("This is an awesome print$(punctuation[1]) wrapping the string '$(x)'$(punctuation[2])")
end

myprint("Hello, World!")
myprint("Hello, World!"; mode=:punctuation)
# Out:
# This is an awesome print wrapping the string 'Hello, World!'
# This is an awesome print, wrapping the string 'Hello, World!'.

# %% [markdown]
# It is important to track the performance of the functions we write.
#
# Below, we leverage the [BenchmarkTools](https://juliaci.github.io/BenchmarkTools.jl/stable/) package for comparing the execution time of a naive implementation of the sum function, `naive_sum`, and a smarter one, `efficient_sum`.
#
# The generic type `T` we associate with the given collection, `xs`, is a placeholder possibly indicating any subtype of `Real`.
# When `efficient_sum` is called with, say, an argument of type `Vector{Int64}`, it has the chance to compile *specialized code*: this is exactly the purpose of multiple dispatch!
#
# Note how we use `@inbounds` and `@simd` macro to speedup the code (remove them if you don't believe, and run the benchmark again!).
# `@inbounds` disables the default bounds checking that must be performed everytime `xs` is accessed.
# `@simd` indicates that the loop can be evaluated out-of-order.

# %%
using BenchmarkTools

# %%
function naive_sum(xs)
    result = 0

    for x in xs 
        result += x
    end

    return result
end
# Out:
# naive_sum (generic function with 1 method)

# %%
# this is nearly the Julia's implementation of the sum function!
function efficient_sum(xs::Vector{T}) where {T<:Real}
    # beware of type stability:
    # this cannot be an Int8(0), or a Float64(0): it has to match T!
    result = zero(T)

    @inbounds @simd for x in xs
        result += x
    end

    return result
end
# Out:
# efficient_sum (generic function with 1 method)

# %%
xs = rand(100000);

# %%
@benchmark naive_sum(xs)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation per sample.
#  Range (min … max):  75.298 μs … 163.169 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     76.974 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   77.947 μs ±   3.834 μs  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#     ▂▃▅▆█▇▇▅▃           ▁                  ▁ ▁   ▁   ▁ ▁       ▂
#   ▇████████████▇▇▇▇▆▇▇█████▆▄▂▄▂▂▂▄▄▄▄▄▅▆▇▅█▆███▇█▇███▆█▆▇▇▇▅▄ █
#   75.3 μs       Histogram: log(frequency) by time      89.2 μs <
#
#  Memory estimate: 16 bytes, allocs estimate: 1.

# %%
@benchmark efficient_sum(xs)
# Out:
# BenchmarkTools.Trial: 10000 samples with 3 evaluations per sample.
#  Range (min … max):  8.964 μs …  25.472 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     9.732 μs               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   9.901 μs ± 681.931 ns  ┊ GC (mean ± σ):  0.00% ± 0.00%
#
#      ▂ ▄▃▅▆▇▇▆█▄▅ ▂ ▂ ▁▁ ▂ ▂ ▁                     ▁          ▂
#   ▇█▇██████████████▇█▇████▇█▆█▅▆▄▅▆▄▅▃▆▁▇▄▆▃▆▃▆▆▆█▇█▆█▆█▆▇▇▆█ █
#   8.96 μs      Histogram: log(frequency) by time      13.2 μs <
#
#  Memory estimate: 16 bytes, allocs estimate: 1.

# %% [markdown]
# # Structures
#
# Julia's custom [composite types](https://docs.julialang.org/en/v1/manual/types/#Composite-Types) are called *structures*.
# They are collections of named fields, and can be instantiated via specific functions called `constructors`.
#
# Structures are are *concrete types*, meaning that their instances are subtypes of some abstract type (the default is `Any`), and are immutable by default.
#
# Below, we play with structures to model a little scenario involving animals.

# %%
abstract type Animal end

# %%
struct Dog <: Animal
    name::String
    age::Int

    function Dog(name, age) 
        if age < 0
            throw(ArgumentError("Age cannot be negative ($(age) is provided)"))
        end
        new(name, age)
    end
end

name(d::Dog) = d.name
age(d::Dog) = d.age

speak(d::Dog) = println("Woof, I am $(name(d)) and I am $(age(d))... woof!")
# Out:
# speak (generic function with 1 method)

# %%
buddy = Dog("Marathon", 7)
speak(buddy)
# Out:
# Woof, I am Marathon and I am 7... woof!

# %%
struct Cat <: Animal
    name::String
    age::Int
    lives::Int

    function Cat(name, age; lives=7)
        if age < 0 || lives < 0
            throw(ArgumentError(
                "Age and lives cannot be negative ($(age) and $(lives) are provided)"))
        end

        new(name, age, lives)
    end
end

name(c::Cat) = c.name
age(c::Cat) = c.age
lives(c::Cat) = c.lives

speak(c::Cat) = println(
    "My name is $(name(c)), I am $(age(c)) and I have $(lives(c)) lives. Miao.")
# Out:
# speak (generic function with 2 methods)

# %%
pal = Cat("Booted Cat", 3)
speak(pal)
# Out:
# My name is Booted Cat, I am 3 and I have 7 lives. Miao.

# %%
struct Axolotl <: Animal
end

try
    speak(Axolotl())
catch
    println("This triggers a method error!")
end
# Out:
# This triggers a method error!

# %%
# We can gracefully handle non-existing dispatches by expliciting a general interface
function speak(a::Animal) 
    throw(ErrorException("Please provide an implementation of speak(a::$(typeof(a)))"))
end
# Out:
# speak (generic function with 3 methods)

# %%
a = Axolotl()
# Out:
# Axolotl()

# %%
speak(a)
# Out:
# Please provide an implementation of speak(a::Axolotl)
#
#
#
# Stacktrace:
#
#  [1] speak(a::Axolotl)
#
#    @ Main ~/.julia/dev/logic-and-machine-learning/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y161sZmlsZQ==.jl:3
#
#  [2] top-level scope
#
#    @ ~/.julia/dev/logic-and-machine-learning/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y163sZmlsZQ==.jl:1
